# %%
from bertviz import model_view, head_view
import torch
import pickle
data = pickle.load(open("/Users/harsha/Documents/enc_attn_list.pkl", 'rb'))
data = list(map(lambda _data: torch.unsqueeze(_data, 0), data))
head_view(data, ["a", "l", "a", "s", "W", "IY1", "L", "AO1", "S", "T", "DH", "AH0", "M"])
# Out:
# <script src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"></script>
#
#         <div id='bertviz-ecbfa88bb8724d79bb3a890de9b7e76a'>
#             <span style="user-select:none">
#                 Layer: <select id="layer"></select>
#
#             </span>
#             <div id='vis'></div>
#         </div>

# %%
from nbconvert import HTMLExporter
import codecs
import nbformat

notebook_name = 'Untitled.ipynb'
output_file_name = 'output.html'

exporter = HTMLExporter()
output_notebook = nbformat.read(notebook_name, as_version=4)

output, resources = exporter.from_notebook_node(output_notebook)
codecs.open(output_file_name, 'w', encoding='utf-8').write(output)
